# %%
from utils.subset_exp import take_subset,plot_model_for_subset

# %%
take_subset(0)
# Out:
# f1 score for AdaBoostClassifier: 0.7013415022743459
# accuracy for AdaBoostClassifier: 0.7965543627640685
# f1 score for CatBoostClassifier: 0.7448731186752053
# accuracy for CatBoostClassifier: 0.8269816154367118
# f1 score for DecisionTreeClassifier: 0.717235312766518
# accuracy for DecisionTreeClassifier: 0.7866081852248143
# f1 score for GaussianNB: 0.36571620057271675
# accuracy for GaussianNB: 0.5766353047426215
# f1 score for GradientBoostingClassifier: 0.7479116559340006
# accuracy for GradientBoostingClassifier: 0.8283625864785555
# f1 score for LGBMClassifier: 0.7659805441612673
# accuracy for LGBMClassifier: 0.8443831062260407
# f1 score for RandomForestClassifier: 0.708078019138862
# accuracy for RandomForestClassifier: 0.7806241595065524
# f1 score for SGDClassifier: 0.47403759508385374
# accuracy for SGDClassifier: 0.6355284715532328
# f1 score for XGBClassifier: 0.7565086491615308
# accuracy for XGBClassifier: 0.8267725540813496

# %%
take_subset(1)
# Out:
# f1 score for AdaBoostClassifier: 0.7052749467167425
# accuracy for AdaBoostClassifier: 0.8001097004957098
# f1 score for CatBoostClassifier: 0.7456170711079305
# accuracy for CatBoostClassifier: 0.8284348946202524
# f1 score for DecisionTreeClassifier: 0.7169386280300124
# accuracy for DecisionTreeClassifier: 0.7863366589854492
# f1 score for GaussianNB: 0.3665444613806742
# accuracy for GaussianNB: 0.5769339605039991
# f1 score for GradientBoostingClassifier: 0.7447249677143842
# accuracy for GradientBoostingClassifier: 0.825253004920528
# f1 score for LGBMClassifier: 0.7670879067752947
# accuracy for LGBMClassifier: 0.845811160755571
# f1 score for RandomForestClassifier: 0.7082632185907185
# accuracy for RandomForestClassifier: 0.7806413408191221
# f1 score for SGDClassifier: 0.36072041835030766
# accuracy for SGDClassifier: 0.5611343112674088
# f1 score for XGBClassifier: 0.7570915042523922
# accuracy for XGBClassifier: 0.8273953987744923

# %%
take_subset(2)
# Out:
# f1 score for AdaBoostClassifier: 0.7205709800792212
# accuracy for AdaBoostClassifier: 0.8154164014880572
# f1 score for CatBoostClassifier: 0.7462482590301786
# accuracy for CatBoostClassifier: 0.8298013506276394
# f1 score for DecisionTreeClassifier: 0.717137609273489
# accuracy for DecisionTreeClassifier: 0.786513871638095
# f1 score for GaussianNB: 0.3652100221822319
# accuracy for GaussianNB: 0.5764275536081158
# f1 score for GradientBoostingClassifier: 0.7469277260785863
# accuracy for GradientBoostingClassifier: 0.8272826720409302
# f1 score for LGBMClassifier: 0.7670005013472883
# accuracy for LGBMClassifier: 0.8454237713258639
# f1 score for RandomForestClassifier: 0.7087858176315045
# accuracy for RandomForestClassifier: 0.7810215421300875
# f1 score for SGDClassifier: 0.33505747184746953
# accuracy for SGDClassifier: 0.5498519096946151
# f1 score for XGBClassifier: 0.7563647832431797
# accuracy for XGBClassifier: 0.8263905640412861

# %%
take_subset(3)
# Out:
# f1 score for AdaBoostClassifier: 0.7126816158344951
# accuracy for AdaBoostClassifier: 0.8072790052793009
# f1 score for CatBoostClassifier: 0.7543834211643252
# accuracy for CatBoostClassifier: 0.8368842128605629
# f1 score for DecisionTreeClassifier: 0.7173013291208435
# accuracy for DecisionTreeClassifier: 0.7865827109437277
# f1 score for GaussianNB: 0.36593052451258457
# accuracy for GaussianNB: 0.5766583566199507
# f1 score for GradientBoostingClassifier: 0.7461171457294733
# accuracy for GradientBoostingClassifier: 0.8268308356759058
# f1 score for LGBMClassifier: 0.7674257524087011
# accuracy for LGBMClassifier: 0.845987348890362
# f1 score for RandomForestClassifier: 0.707986545058101
# accuracy for RandomForestClassifier: 0.7804929440070942
# f1 score for SGDClassifier: 0.38772156065830216
# accuracy for SGDClassifier: 0.6062900157029223
# f1 score for XGBClassifier: 0.7593110860990275
# accuracy for XGBClassifier: 0.8307488372600772

# %%
take_subset(4)
# Out:
# f1 score for AdaBoostClassifier: 0.6969962785417723
# accuracy for AdaBoostClassifier: 0.7922454824724386
# f1 score for CatBoostClassifier: 0.7520916905444126
# accuracy for CatBoostClassifier: 0.8353598842335395
# f1 score for DecisionTreeClassifier: 0.7166199693635984
# accuracy for DecisionTreeClassifier: 0.7860481949038837
# f1 score for GaussianNB: 0.3663233146065826
# accuracy for GaussianNB: 0.5768641138213422
# f1 score for GradientBoostingClassifier: 0.7483861601240258
# accuracy for GradientBoostingClassifier: 0.8292135777314933
# f1 score for LGBMClassifier: 0.7666844337694871
# accuracy for LGBMClassifier: 0.8451926698333347
# f1 score for RandomForestClassifier: 0.7084766986364366
# accuracy for RandomForestClassifier: 0.7807941681747284
# f1 score for SGDClassifier: 0.4096989829444362
# accuracy for SGDClassifier: 0.6125923611695268
# f1 score for XGBClassifier: 0.7578846257812334
# accuracy for XGBClassifier: 0.8282112580550224

# %%
plot_model_for_subset(0)

# %%
plot_model_for_subset(1)

# %%
plot_model_for_subset(2)

# %%
plot_model_for_subset(3)

# %%
plot_model_for_subset(4)
